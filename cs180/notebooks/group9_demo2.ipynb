# %% [markdown]
# # Demo Code for Vision Transformer Model
#
# This notebook will generate the predictions from the potato_test test dataset using the model from deeplearning_vit.pt and deeplearning_vit.ipynb
# The predictions will be contained at the csv file deeplearning_vit_predictions.csv

# %% [markdown]
# ## Imports

# %%
import os
import torch
from torchvision import transforms
from PIL import Image
import pandas as pd
import numpy as np
import torch.nn as nn

# %% [markdown]
# ## Variables and Parameters

# %%
EPOCHS = 200
BATCH_SIZE = 32  # Reduced from 64 for better gradient updates
IMG_SIZE = 224
PATCH_SIZE = 16
IN_CHANNELS = 3
EMBED_DIM = 256
NUM_PATCHES = (IMG_SIZE // PATCH_SIZE) ** 2
NUM_HEADS = 8
NUM_ENCODERS = 6
NUM_CLASSES = 6
LEARNING_RATE = 1e-4  # Reduced from 3e-4
DROPOUT = 0.1
ACTIVATION = 'gelu'
WARMUP_EPOCHS = 5  # For learning rate warmup

# %% [markdown]
# ## Model

# %%
class PatchEmbedding(nn.Module):
    def __init__(self, in_channels, patch_size, embed_dim, num_patches, dropout):
        super(PatchEmbedding, self).__init__()
        self.patcher = nn.Sequential(
            nn.Conv2d(in_channels=in_channels, out_channels=embed_dim, 
                      kernel_size=patch_size, stride=patch_size),
            nn.Flatten(2)
        )
        self.cls_token = nn.Parameter(torch.zeros(1, 1, embed_dim))
        self.pos_embed = nn.Parameter(torch.zeros(1, num_patches + 1, embed_dim))
        self.dropout = nn.Dropout(dropout)
        
        # Initialize weights properly
        nn.init.trunc_normal_(self.cls_token, std=.02)
        nn.init.trunc_normal_(self.pos_embed, std=.02)

    def forward(self, x):
        x = self.patcher(x).permute(0, 2, 1)
        cls_tokens = self.cls_token.expand(x.size(0), -1, -1)
        x = torch.cat((cls_tokens, x), dim=1)
        x = x + self.pos_embed
        return self.dropout(x)

class ViT(nn.Module):
    def __init__(self):
        super(ViT, self).__init__()
        self.patch_embed = PatchEmbedding(IN_CHANNELS, PATCH_SIZE, EMBED_DIM, NUM_PATCHES, DROPOUT)
        self.norm = nn.LayerNorm(EMBED_DIM)  # Additional layer norm
        encoder_layer = nn.TransformerEncoderLayer(
            d_model=EMBED_DIM, 
            nhead=NUM_HEADS, 
            activation=ACTIVATION,
            dropout=DROPOUT,
            batch_first=True  # Use batch_first for better compatibility
        )
        self.transformer = nn.TransformerEncoder(encoder_layer, num_layers=NUM_ENCODERS)
        self.mlp_head = nn.Sequential(
            nn.LayerNorm(EMBED_DIM),
            nn.Linear(EMBED_DIM, EMBED_DIM//2),  # Narrower
            nn.GELU(),
            nn.Dropout(0.3),
            nn.Linear(EMBED_DIM//2, EMBED_DIM//4),
            nn.GELU(),
            nn.Dropout(0.2),
            nn.Linear(EMBED_DIM//4, NUM_CLASSES)
        )
    def forward(self, x):
        x = self.patch_embed(x)
        x = self.norm(x)  # Additional normalization
        x = self.transformer(x)
        return self.mlp_head(x[:, 0])  # Class token

# %% [markdown]
# ## Setup and Preprocessing

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = ViT().to(device)
# Define the same transforms used during training
transform = transforms.Compose([
    transforms.Resize((224, 224)),  # Adjust to your model's expected input size
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])  # ImageNet stats
])

# Class names mapping
class_names = {
    0: "Bacteria",
    1: "Fungi",
    2: "Healthy",
    3: "Pest",
    4: "Phytopthora",
    5: "Virus"
}

# %% [markdown]
# ## Using the Model and Generating Predictions

# %%
def predict_folder(model, folder_path, output_csv="group9_model2_prediction"):
    """
    Predict classes for all images in a folder and save results to CSV sorted by numerical filename.
    
    Args:
        model: Trained PyTorch model
        folder_path: Path to folder containing images
        output_csv: Path to save the predictions CSV file
    """
    # Get all image files in the folder
    image_files = [f for f in os.listdir(folder_path) 
                 if f.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.tiff'))]
    
    if not image_files:
        print(f"No images found in {folder_path}")
        return
    
    # Prepare to store predictions
    predictions = []
    
    # Set model to evaluation mode
    model.eval()
    
    # Process each image
    for img_file in image_files:
        try:
            img_path = os.path.join(folder_path, img_file)
            
            # Load and preprocess image
            img = Image.open(img_path).convert('RGB')
            img_tensor = transform(img).unsqueeze(0).to(device)  # Add batch dimension
            
            # Make prediction
            with torch.no_grad():
                outputs = model(img_tensor)
                probs = torch.nn.functional.softmax(outputs, dim=1)
                conf, pred = torch.max(probs, 1)
            
            # Get class name and confidence
            class_id = pred.item()
            class_name = class_names.get(class_id, "Unknown")
            confidence = conf.item()
            
            # Extract number from filename (assuming format like "1.jpg", "2.png", etc.)
            file_num = int(''.join(filter(str.isdigit, img_file)))
            
            predictions.append({
                'filename': img_file,
                'file_number': file_num,  # Add numerical value for sorting
                'class_id': class_id,
                'class_name': class_name,
                'confidence': confidence
            })
            
            print(f"{img_file}: {class_name} (confidence: {confidence:.2f})")
            
        except Exception as e:
            print(f"Error processing {img_file}: {str(e)}")
            predictions.append({
                'filename': img_file,
                'file_number': -1,  # Default for error cases
                'class_id': -1,
                'class_name': 'Error',
                'confidence': 0.0
            })
    
    # Convert to DataFrame and sort by numerical filename
    df = pd.DataFrame(predictions)
    df = df.sort_values(by='file_number')
    
    # Drop the temporary file_number column if you don't want it in the output
    df = df.drop(columns=['file_number'])
    
    # Save to CSV
    df.to_csv(output_csv, index=False)
    print(f"\nPredictions saved to {output_csv}, sorted by numerical filename")
    
    return df
    
# Load your trained model
model = ViT().to(device)
model.load_state_dict(torch.load("deeplearning_vit.pt")) ## Change your model name here
model.eval()


folder_path = "potato_test"
predict_folder(model, folder_path, "group9_model2_predictions") ## Change your csv name here
# Out:
# 0.jpeg: Healthy (confidence: 0.36)
# 1.jpeg: Healthy (confidence: 0.77)
# 10.jpeg: Healthy (confidence: 0.84)
# 100.jpeg: Phytopthora (confidence: 0.68)
# 101.jpeg: Bacteria (confidence: 0.78)
# 102.jpeg: Fungi (confidence: 0.44)
# 103.jpeg: Healthy (confidence: 0.58)
# 104.jpeg: Healthy (confidence: 0.42)
# 105.jpeg: Virus (confidence: 0.57)
# 106.jpeg: Virus (confidence: 0.54)
# 107.jpeg: Pest (confidence: 0.29)
# 108.jpeg: Pest (confidence: 0.54)
# 109.jpeg: Fungi (confidence: 0.38)
# 11.jpeg: Healthy (confidence: 0.69)
# 110.jpeg: Virus (confidence: 0.35)
# 111.jpeg: Fungi (confidence: 0.68)
# 112.jpeg: Fungi (confidence: 0.58)
# 113.jpeg: Bacteria (confidence: 0.45)
# 114.jpeg: Fungi (confidence: 0.60)
# 115.jpeg: Fungi (confidence: 0.42)
# 116.jpeg: Virus (confidence: 0.49)
# 117.jpeg: Phytopthora (confidence: 0.56)
# 118.jpeg: Bacteria (confidence: 0.46)
# 119.jpeg: Fungi (confidence: 0.71)
# 12.jpeg: Virus (confidence: 0.62)
# 120.jpeg: Fungi (confidence: 0.61)
# 121.jpeg: Virus (confidence: 0.36)
# 122.jpeg: Virus (confidence: 0.34)
# 123.jpeg: Fungi (confidence: 0.40)
# 124.jpeg: Fungi (confidence: 0.51)
# 125.jpeg: Fungi (confidence: 0.68)
# 126.jpeg: Bacteria (confidence: 0.42)
# 127.jpeg: Pest (confidence: 0.66)
# 128.jpeg: Fungi (confidence: 0.55)
# 129.jpeg: Virus (confidence: 0.52)
# 13.jpeg: Healthy (confidence: 0.92)
# 130.jpeg: Fungi (confidence: 0.64)
# 131.jpeg: Fungi (confidence: 0.77)
# 132.jpeg: Fungi (confidence: 0.82)
# 133.jpeg: Fungi (confidence: 0.48)
# 134.jpeg: Fungi (confidence: 0.35)
# 135.jpeg: Healthy (confidence: 0.41)
# 136.jpeg: Fungi (confidence: 0.59)
# 137.jpeg: Virus (confidence: 0.39)
# 138.jpeg: Fungi (confidence: 0.47)
# 139.jpeg: Bacteria (confidence: 0.66)
# 14.jpeg: Virus (confidence: 0.91)
# 140.jpeg: Pest (confidence: 0.36)
# 141.jpeg: Pest (confidence: 0.61)
# 142.jpeg: Bacteria (confidence: 0.88)
# 143.jpeg: Pest (confidence: 0.31)
# 144.jpeg: Healthy (confidence: 0.51)
# 145.jpeg: Fungi (confidence: 0.78)
# 146.jpeg: Pest (confidence: 0.38)
# 147.jpeg: Fungi (confidence: 0.47)
# 148.jpeg: Fungi (confidence: 0.81)
# 149.jpeg: Fungi (confidence: 0.47)
# 15.jpeg: Phytopthora (confidence: 0.86)
# 150.jpeg: Fungi (confidence: 0.58)
# 151.jpeg: Fungi (confidence: 0.53)
# 152.jpeg: Healthy (confidence: 0.39)
# 153.jpeg: Fungi (confidence: 0.70)
# 154.jpeg: Pest (confidence: 0.37)
# 155.jpeg: Virus (confidence: 0.67)
# 156.jpeg: Bacteria (confidence: 0.48)
# 157.jpeg: Bacteria (confidence: 0.58)
# 158.jpeg: Pest (confidence: 0.32)
# 159.jpeg: Pest (confidence: 0.78)
# 16.jpeg: Fungi (confidence: 0.33)
# 160.jpeg: Pest (confidence: 0.49)
# 161.jpeg: Fungi (confidence: 0.37)
# 162.jpeg: Fungi (confidence: 0.40)
# 163.jpeg: Healthy (confidence: 0.67)
# 164.jpeg: Fungi (confidence: 0.35)
# 165.jpeg: Bacteria (confidence: 0.26)
# 166.jpeg: Pest (confidence: 0.33)
# 167.jpeg: Fungi (confidence: 0.39)
# 168.jpeg: Pest (confidence: 0.66)
# 169.jpeg: Healthy (confidence: 0.54)
# 17.jpeg: Virus (confidence: 0.28)
# 170.jpeg: Virus (confidence: 0.46)
# 171.jpeg: Pest (confidence: 0.43)
# 172.jpeg: Healthy (confidence: 0.91)
# 173.jpeg: Phytopthora (confidence: 0.52)
# 174.jpeg: Pest (confidence: 0.47)
# 175.jpeg: Phytopthora (confidence: 0.47)
# 176.jpeg: Pest (confidence: 0.49)
# 177.jpeg: Phytopthora (confidence: 0.84)
# 178.jpeg: Phytopthora (confidence: 0.48)
# 179.jpeg: Virus (confidence: 0.27)
# 18.jpeg: Healthy (confidence: 0.60)
# 180.jpeg: Virus (confidence: 0.51)
# 181.jpeg: Pest (confidence: 0.45)
# 182.jpeg: Pest (confidence: 0.54)
# 183.jpeg: Pest (confidence: 0.81)
# 184.jpeg: Pest (confidence: 0.80)
# 185.jpeg: Pest (confidence: 0.60)
# 186.jpeg: Phytopthora (confidence: 0.85)
# 187.jpeg: Pest (confidence: 0.86)
# 188.jpeg: Pest (confidence: 0.67)
# 189.jpeg: Pest (confidence: 0.75)
# 19.jpeg: Fungi (confidence: 0.43)
# 190.jpeg: Virus (confidence: 0.34)
# 191.jpeg: Fungi (confidence: 0.54)
# 192.jpeg: Phytopthora (confidence: 0.57)
# 193.jpeg: Virus (confidence: 0.30)
# 194.jpeg: Fungi (confidence: 0.37)
# 195.jpeg: Phytopthora (confidence: 0.53)
# 196.jpeg: Pest (confidence: 0.75)
# 197.jpeg: Pest (confidence: 0.65)
# 198.jpeg: Pest (confidence: 0.45)
# 199.jpeg: Pest (confidence: 0.54)
# 2.jpeg: Healthy (confidence: 0.56)
# 20.jpeg: Bacteria (confidence: 0.91)
# 200.jpeg: Pest (confidence: 0.40)
# 201.jpeg: Pest (confidence: 0.84)
# 202.jpeg: Phytopthora (confidence: 0.57)
# 203.jpeg: Fungi (confidence: 0.46)
# 204.jpeg: Pest (confidence: 0.43)
# 205.jpeg: Virus (confidence: 0.73)
# 206.jpeg: Pest (confidence: 0.50)
# 207.jpeg: Virus (confidence: 0.66)
# 208.jpeg: Phytopthora (confidence: 0.40)
# 209.jpeg: Phytopthora (confidence: 0.52)
# 21.jpeg: Healthy (confidence: 0.26)
# 210.jpeg: Fungi (confidence: 0.50)
# 211.jpeg: Fungi (confidence: 0.64)
# 212.jpeg: Phytopthora (confidence: 0.46)
# 213.jpeg: Fungi (confidence: 0.34)
# 214.jpeg: Fungi (confidence: 0.47)
# 215.jpeg: Bacteria (confidence: 0.51)
# 216.jpeg: Fungi (confidence: 0.50)
# 217.jpeg: Phytopthora (confidence: 0.94)
# 218.jpeg: Phytopthora (confidence: 0.85)
# 219.jpeg: Phytopthora (confidence: 0.78)
# 22.jpeg: Virus (confidence: 0.71)
# 220.jpeg: Fungi (confidence: 0.44)
# 221.jpeg: Phytopthora (confidence: 0.81)
# 222.jpeg: Phytopthora (confidence: 0.90)
# 223.jpeg: Phytopthora (confidence: 0.85)
# 224.jpeg: Phytopthora (confidence: 0.85)
# 225.jpeg: Phytopthora (confidence: 0.94)
# 226.jpeg: Phytopthora (confidence: 0.94)
# 227.jpeg: Phytopthora (confidence: 0.87)
# 228.jpeg: Phytopthora (confidence: 0.90)
# 229.jpeg: Fungi (confidence: 0.59)
# 23.jpeg: Virus (confidence: 0.63)
# 230.jpeg: Fungi (confidence: 0.51)
# 231.jpeg: Phytopthora (confidence: 0.94)
# 232.jpeg: Phytopthora (confidence: 0.93)
# 233.jpeg: Phytopthora (confidence: 0.85)
# 234.jpeg: Phytopthora (confidence: 0.52)
# 235.jpeg: Phytopthora (confidence: 0.92)
# 236.jpeg: Phytopthora (confidence: 0.66)
# 237.jpeg: Virus (confidence: 0.86)
# 238.jpeg: Phytopthora (confidence: 0.83)
# 239.jpeg: Phytopthora (confidence: 0.85)
# 24.jpeg: Bacteria (confidence: 0.91)
# 240.jpeg: Phytopthora (confidence: 0.64)
# 241.jpeg: Phytopthora (confidence: 0.91)
# 242.jpeg: Phytopthora (confidence: 0.35)
# 243.jpeg: Fungi (confidence: 0.44)
# 244.jpeg: Phytopthora (confidence: 0.60)
# 245.jpeg: Phytopthora (confidence: 0.84)
# 246.jpeg: Phytopthora (confidence: 0.86)
# 247.jpeg: Phytopthora (confidence: 0.90)
# 248.jpeg: Virus (confidence: 0.45)
# 249.jpeg: Virus (confidence: 0.82)
# 25.jpeg: Virus (confidence: 0.47)
# 250.jpeg: Virus (confidence: 0.68)
# 251.jpeg: Virus (confidence: 0.79)
# 252.jpeg: Bacteria (confidence: 0.90)
# 253.jpeg: Virus (confidence: 0.86)
# 254.jpeg: Virus (confidence: 0.71)
# 255.jpeg: Virus (confidence: 0.92)
# 256.jpeg: Phytopthora (confidence: 0.38)
# 257.jpeg: Virus (confidence: 0.89)
# 258.jpeg: Virus (confidence: 0.74)
# 259.jpeg: Virus (confidence: 0.73)
# 26.jpeg: Bacteria (confidence: 0.87)
# 260.jpeg: Virus (confidence: 0.44)
# 261.jpeg: Virus (confidence: 0.66)
# 262.jpeg: Virus (confidence: 0.75)
# 263.jpeg: Virus (confidence: 0.91)
# 264.jpeg: Virus (confidence: 0.78)
# 265.jpeg: Virus (confidence: 0.87)
# 266.jpeg: Virus (confidence: 0.83)
# 267.jpeg: Virus (confidence: 0.93)
# 268.jpeg: Virus (confidence: 0.91)
# 269.jpeg: Healthy (confidence: 0.64)
# 27.jpeg: Bacteria (confidence: 0.47)
# 270.jpeg: Virus (confidence: 0.65)
# 271.jpeg: Bacteria (confidence: 0.79)
# 272.jpeg: Virus (confidence: 0.71)
# 273.jpeg: Virus (confidence: 0.93)
# 274.jpeg: Virus (confidence: 0.66)
# 275.jpeg: Virus (confidence: 0.80)
# 276.jpeg: Virus (confidence: 0.55)
# 277.jpeg: Virus (confidence: 0.77)
# 278.jpeg: Virus (confidence: 0.62)
# 279.jpeg: Bacteria (confidence: 0.44)
# 28.jpeg: Bacteria (confidence: 0.86)
# 280.jpeg: Virus (confidence: 0.86)
# 281.jpeg: Virus (confidence: 0.91)
# 282.jpeg: Fungi (confidence: 0.31)
# 283.jpeg: Virus (confidence: 0.88)
# 284.jpeg: Virus (confidence: 0.89)
# 285.jpeg: Virus (confidence: 0.93)
# 286.jpeg: Virus (confidence: 0.83)
# 287.jpeg: Virus (confidence: 0.74)
# 288.jpeg: Virus (confidence: 0.90)
# 289.jpeg: Phytopthora (confidence: 0.43)
# 29.jpeg: Bacteria (confidence: 0.87)
# 290.jpeg: Virus (confidence: 0.42)
# 291.jpeg: Virus (confidence: 0.50)
# 292.jpeg: Virus (confidence: 0.88)
# 293.jpeg: Virus (confidence: 0.38)
# 294.jpeg: Virus (confidence: 0.83)
# 295.jpeg: Fungi (confidence: 0.47)
# 296.jpeg: Virus (confidence: 0.53)
# 297.jpeg: Virus (confidence: 0.41)
# 298.jpeg: Virus (confidence: 0.64)
# 299.jpeg: Pest (confidence: 0.56)
# 3.jpeg: Healthy (confidence: 0.54)
# 30.jpeg: Bacteria (confidence: 0.88)
# 300.jpeg: Bacteria (confidence: 0.45)
# 31.jpeg: Bacteria (confidence: 0.89)
# 32.jpeg: Bacteria (confidence: 0.56)
# 33.jpeg: Bacteria (confidence: 0.89)
# 34.jpeg: Virus (confidence: 0.50)
# 35.jpeg: Bacteria (confidence: 0.85)
# 36.jpeg: Bacteria (confidence: 0.77)
# 37.jpeg: Bacteria (confidence: 0.91)
# 38.jpeg: Bacteria (confidence: 0.90)
# 39.jpeg: Bacteria (confidence: 0.91)
# 4.jpeg: Healthy (confidence: 0.37)
# 40.jpeg: Bacteria (confidence: 0.91)
# 41.jpeg: Bacteria (confidence: 0.91)
# 42.jpeg: Bacteria (confidence: 0.60)
# 43.jpeg: Bacteria (confidence: 0.90)
# 44.jpeg: Bacteria (confidence: 0.91)
# 45.jpeg: Fungi (confidence: 0.45)
# 46.jpeg: Bacteria (confidence: 0.91)
# 47.jpeg: Bacteria (confidence: 0.90)
# 48.jpeg: Bacteria (confidence: 0.87)
# 49.jpeg: Bacteria (confidence: 0.89)
# 5.jpeg: Healthy (confidence: 0.48)
# 50.jpeg: Bacteria (confidence: 0.90)
# 51.jpeg: Bacteria (confidence: 0.87)
# 52.jpeg: Bacteria (confidence: 0.90)
# 53.jpeg: Virus (confidence: 0.52)
# 54.jpeg: Virus (confidence: 0.36)
# 55.jpeg: Bacteria (confidence: 0.85)
# 56.jpeg: Bacteria (confidence: 0.85)
# 57.jpeg: Bacteria (confidence: 0.85)
# 58.jpeg: Bacteria (confidence: 0.88)
# 59.jpeg: Bacteria (confidence: 0.89)
# 6.jpeg: Healthy (confidence: 0.83)
# 60.jpeg: Bacteria (confidence: 0.87)
# 61.jpeg: Bacteria (confidence: 0.90)
# 62.jpeg: Bacteria (confidence: 0.87)
# 63.jpeg: Bacteria (confidence: 0.91)
# 64.jpeg: Bacteria (confidence: 0.90)
# 65.jpeg: Bacteria (confidence: 0.90)
# 66.jpeg: Bacteria (confidence: 0.78)
# 67.jpeg: Virus (confidence: 0.75)
# 68.jpeg: Virus (confidence: 0.79)
# 69.jpeg: Bacteria (confidence: 0.87)
# 7.jpeg: Fungi (confidence: 0.50)
# 70.jpeg: Bacteria (confidence: 0.63)
# 71.jpeg: Bacteria (confidence: 0.91)
# 72.jpeg: Bacteria (confidence: 0.74)
# 73.jpeg: Bacteria (confidence: 0.90)
# 74.jpeg: Bacteria (confidence: 0.86)
# 75.jpeg: Bacteria (confidence: 0.71)
# 76.jpeg: Bacteria (confidence: 0.86)
# 77.jpeg: Fungi (confidence: 0.61)
# 78.jpeg: Fungi (confidence: 0.66)
# 79.jpeg: Fungi (confidence: 0.46)
# 8.jpeg: Virus (confidence: 0.57)
# 80.jpeg: Fungi (confidence: 0.65)
# 81.jpeg: Fungi (confidence: 0.76)
# 82.jpeg: Fungi (confidence: 0.35)
# 83.jpeg: Healthy (confidence: 0.75)
# 84.jpeg: Bacteria (confidence: 0.59)
# 85.jpeg: Pest (confidence: 0.76)
# 86.jpeg: Bacteria (confidence: 0.81)
# 87.jpeg: Fungi (confidence: 0.34)
# 88.jpeg: Phytopthora (confidence: 0.42)
# 89.jpeg: Bacteria (confidence: 0.88)
# 9.jpeg: Bacteria (confidence: 0.76)
# 90.jpeg: Bacteria (confidence: 0.43)
# 91.jpeg: Phytopthora (confidence: 0.31)
# 92.jpeg: Fungi (confidence: 0.57)
# 93.jpeg: Fungi (confidence: 0.68)
# 94.jpeg: Fungi (confidence: 0.66)
# 95.jpeg: Fungi (confidence: 0.75)
# 96.jpeg: Phytopthora (confidence: 0.54)
# 97.jpeg: Phytopthora (confidence: 0.40)
# 98.jpeg: Fungi (confidence: 0.75)
# 99.jpeg: Fungi (confidence: 0.68)
#
# Predictions saved to my_predictions_67.csv, sorted by numerical filename
#      filename  class_id class_name  confidence
# 0      0.jpeg         2    Healthy    0.359010
# 1      1.jpeg         2    Healthy    0.770729
# 112    2.jpeg         2    Healthy    0.560473
# 223    3.jpeg         2    Healthy    0.540117
# 235    4.jpeg         2    Healthy    0.372226
# ..        ...       ...        ...         ...
# 219  296.jpeg         5      Virus    0.533953
# 220  297.jpeg         5      Virus    0.407108
# 221  298.jpeg         5      Virus    0.641145
# 222  299.jpeg         3       Pest    0.564876
# 225  300.jpeg         0   Bacteria    0.445121
#
# [301 rows x 4 columns]
